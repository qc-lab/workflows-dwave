# %%
# %cd ..
# Out:
# /Users/jzawalska/Coding/workflows-dwave

# %%
from solver import solver
from visualize import create_energy_histogram, draw_workflow_schema

# %%
input_file = "data/workflows/1000genome_22_tasks.json"
machines_file = "data/machines/cyfronet.json"
output_file = "data/results/result.json"

deadline = 1000
method = "CQM_solver" #"Gurobi_solver"

# %%
solver = solver(input_file, machines_file, output_file, deadline, method)
solver.solve()
# Out:
# Finished in 19.68878722190857 seconds.

# %%
create_energy_histogram("data/results/cqm_results.pkl")

# %%
draw_workflow_schema(output_file)
