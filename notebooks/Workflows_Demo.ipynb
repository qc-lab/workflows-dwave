# %%
# %cd ..

# %%
# !pip install -r requirements.txt

# %%
from src.solvers.solver_util import get_solver
from src.visualization.visualize import create_energy_histogram, draw_workflow_schema

# %%
input_file = "data/workflows/srasearch_22_tasks.json"
machines_file = "data/machines/cyfronet.json"
output_file = "data/results/result.json"

deadline = 1000
method = "CQM_solver" #"Gurobi_solver"

# %%
solver = get_solver(method)(input_file, machines_file, output_file, deadline)

solver.solve()
# Out:
# Finished in 19.438 seconds.

# %%
create_energy_histogram("data/results/cqm_results.pkl")

# %%
draw_workflow_schema(output_file)
